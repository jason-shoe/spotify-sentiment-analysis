# %%
import pandas as pd
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

# %%
songList = pd.read_csv('songlistFeatures.csv',index_col=0)

# %%
moods = ['happy','sad','energetic','calm']
for x in moods:
    print(x,': ',len(songList[songList['p_mood']==x]))
# Out:
# happy :  1597
# sad :  1863
# energetic :  1640
# calm :  2658

# %%
a = list(songList.columns)
songList[a]
# Out:
#      p_mood   p_creator        p_name  pitch_mean  pitch_variance  \
# 0     happy     Spotify  Mood Booster    0.242262        0.096074
# 1     happy     Spotify  Mood Booster    0.231950        0.112299
# 2     happy     Spotify  Mood Booster    0.319214        0.112336
# 3     happy     Spotify  Mood Booster    0.380226        0.110329
# 4     happy     Spotify  Mood Booster    0.318760        0.111981
# ...     ...         ...           ...         ...             ...
# 7753  happy  kristy bae       b happy    0.291726        0.101888
# 7754  happy  kristy bae       b happy    0.467214        0.099337
# 7755  happy  kristy bae       b happy    0.211532        0.084756
# 7756  happy  kristy bae       b happy    0.306367        0.090692
# 7757  happy  kristy bae       b happy    0.306629        0.100120
#
#       timbre_mean  timbre_variance  intensity_mean  intensity_variance  \
# 0       -3.659996         0.096074      -25.035929          120.303653
# 1       -2.608847         0.112299      -28.505833           79.213738
# 2        0.432143         0.112336      -33.926976          196.795561
# 3       -4.860290         0.110329      -20.138071           99.793764
# 4       -2.943942         0.111981      -30.348714          237.132436
# ...           ...              ...             ...                 ...
# 7753    -4.274258         0.101888      -27.486095           77.085317
# 7754     5.623792         0.099337      -25.249405           67.872885
# 7755    -6.139149         0.084756      -22.202738           38.573939
# 7756    -6.010048         0.090692      -35.200310           48.322032
# 7757     6.574087         0.100120      -26.112024          101.919824
#
#       rhythm_mean       rhythm_
# 0        0.305883  2.999075e-06
# 1        0.202729  9.355656e-07
# 2        0.243865  1.083542e-06
# 3        0.403649  1.818510e-02
# 4        0.318681  1.501005e-05
# ...           ...           ...
# 7753     0.205065  5.593137e-06
# 7754     0.201060  4.812368e-04
# 7755     0.208287  4.568902e-06
# 7756     0.299791  9.835346e-06
# 7757     0.324891  2.185297e-05
#
# [7758 rows x 11 columns]

# %%
group_by_mood = songList.groupby(by=['p_mood'])
group_by_mood.count()
# Out:
#            p_creator  p_name  pitch_mean  pitch_variance  timbre_mean  \
# p_mood
# calm            2658    2658        2658            2658         2658
# energetic       1640    1640        1640            1640         1640
# happy           1597    1597        1597            1597         1597
# sad             1863    1863        1863            1863         1863
#
#            timbre_variance  intensity_mean  intensity_variance  rhythm_mean  \
# p_mood
# calm                  2658            2658                2658         2658
# energetic             1640            1640                1640         1640
# happy                 1597            1597                1597         1597
# sad                   1863            1863                1863         1863
#
#            rhythm_
# p_mood
# calm          2658
# energetic     1640
# happy         1597
# sad           1863

# %%
group_by_mood = songList.groupby(by=['p_mood'])
group_by_mood.mean()
# Out:
#            pitch_mean  pitch_variance  timbre_mean  timbre_variance  \
# p_mood
# calm         0.267671        0.093845    -7.936825         0.093845
# energetic    0.311418        0.092929     4.203615         0.092929
# happy        0.300951        0.093522     1.828373         0.093522
# sad          0.259976        0.093273    -4.269061         0.093273
#
#            intensity_mean  intensity_variance  rhythm_mean   rhythm_
# p_mood
# calm           -32.447802           68.991447     0.289582  0.003126
# energetic      -26.279412          105.340561     0.266073  0.000915
# happy          -27.623834           99.602907     0.268532  0.001210
# sad            -30.392586           84.610989     0.273822  0.002410

# %%
songList.groupby(by=['p_mood']).corr()
# Out:
#                               pitch_mean  pitch_variance  timbre_mean  \
# p_mood
# calm      pitch_mean            1.000000        0.272848     0.338715
#           pitch_variance        0.272848        1.000000    -0.103209
#           timbre_mean           0.338715       -0.103209     1.000000
#           timbre_variance       0.272848        1.000000    -0.103209
#           intensity_mean        0.038772       -0.018195     0.285846
#           intensity_variance    0.081012        0.102676     0.347267
#           rhythm_mean          -0.045169        0.025669    -0.117340
#           rhythm_              -0.051444        0.000928    -0.153314
# energetic pitch_mean            1.000000        0.009174     0.280576
#           pitch_variance        0.009174        1.000000    -0.208436
#           timbre_mean           0.280576       -0.208436     1.000000
#           timbre_variance       0.009174        1.000000    -0.208436
#           intensity_mean        0.083407       -0.144825     0.311044
#           intensity_variance    0.103769        0.117492     0.204595
#           rhythm_mean          -0.040320        0.008002     0.000787
#           rhythm_              -0.014739       -0.009894    -0.054422
# happy     pitch_mean            1.000000        0.078014     0.337759
#           pitch_variance        0.078014        1.000000    -0.177798
#           timbre_mean           0.337759       -0.177798     1.000000
#           timbre_variance       0.078014        1.000000    -0.177798
#           intensity_mean        0.121216       -0.156824     0.343123
#           intensity_variance    0.280040        0.105350     0.331839
#           rhythm_mean          -0.042093        0.088638    -0.121839
#           rhythm_              -0.022956        0.066850    -0.140907
# sad       pitch_mean            1.000000        0.273956     0.282300
#           pitch_variance        0.273956        1.000000    -0.093242
#           timbre_mean           0.282300       -0.093242     1.000000
#           timbre_variance       0.273956        1.000000    -0.093242
#           intensity_mean        0.047420       -0.042359     0.322329
#           intensity_variance    0.146523        0.134048     0.292267
#           rhythm_mean          -0.025829        0.013663    -0.046619
#           rhythm_              -0.039746       -0.014424    -0.039150
#
#                               timbre_variance  intensity_mean  \
# p_mood
# calm      pitch_mean                 0.272848        0.038772
#           pitch_variance             1.000000       -0.018195
#           timbre_mean               -0.103209        0.285846
#           timbre_variance            1.000000       -0.018195
#           intensity_mean            -0.018195        1.000000
#           intensity_variance         0.102676        0.260705
#           rhythm_mean                0.025669       -0.083175
#           rhythm_                    0.000928       -0.110430
# energetic pitch_mean                 0.009174        0.083407
#           pitch_variance             1.000000       -0.144825
#           timbre_mean               -0.208436        0.311044
#           timbre_variance            1.000000       -0.144825
#           intensity_mean            -0.144825        1.000000
#           intensity_variance         0.117492       -0.021999
#           rhythm_mean                0.008002       -0.022173
#           rhythm_                   -0.009894       -0.030571
# happy     pitch_mean                 0.078014        0.121216
#           pitch_variance             1.000000       -0.156824
#           timbre_mean               -0.177798        0.343123
#           timbre_variance            1.000000       -0.156824
#           intensity_mean            -0.156824        1.000000
#           intensity_variance         0.105350        0.048477
#           rhythm_mean                0.088638       -0.096171
#           rhythm_                    0.066850       -0.139661
# sad       pitch_mean                 0.273956        0.047420
#           pitch_variance             1.000000       -0.042359
#           timbre_mean               -0.093242        0.322329
#           timbre_variance            1.000000       -0.042359
#           intensity_mean            -0.042359        1.000000
#           intensity_variance         0.134048        0.135934
#           rhythm_mean                0.013663       -0.068244
#           rhythm_                   -0.014424       -0.070536
#
#                               intensity_variance  rhythm_mean   rhythm_
# p_mood
# calm      pitch_mean                    0.081012    -0.045169 -0.051444
#           pitch_variance                0.102676     0.025669  0.000928
#           timbre_mean                   0.347267    -0.117340 -0.153314
#           timbre_variance               0.102676     0.025669  0.000928
#           intensity_mean                0.260705    -0.083175 -0.110430
#           intensity_variance            1.000000    -0.076214 -0.102880
#           rhythm_mean                  -0.076214     1.000000  0.372601
#           rhythm_                      -0.102880     0.372601  1.000000
# energetic pitch_mean                    0.103769    -0.040320 -0.014739
#           pitch_variance                0.117492     0.008002 -0.009894
#           timbre_mean                   0.204595     0.000787 -0.054422
#           timbre_variance               0.117492     0.008002 -0.009894
#           intensity_mean               -0.021999    -0.022173 -0.030571
#           intensity_variance            1.000000     0.005797 -0.016320
#           rhythm_mean                   0.005797     1.000000  0.177447
#           rhythm_                      -0.016320     0.177447  1.000000
# happy     pitch_mean                    0.280040    -0.042093 -0.022956
#           pitch_variance                0.105350     0.088638  0.066850
#           timbre_mean                   0.331839    -0.121839 -0.140907
#           timbre_variance               0.105350     0.088638  0.066850
#           intensity_mean                0.048477    -0.096171 -0.139661
#           intensity_variance            1.000000    -0.048465 -0.066296
#           rhythm_mean                  -0.048465     1.000000  0.268560
#           rhythm_                      -0.066296     0.268560  1.000000
# sad       pitch_mean                    0.146523    -0.025829 -0.039746
#           pitch_variance                0.134048     0.013663 -0.014424
#           timbre_mean                   0.292267    -0.046619 -0.039150
#           timbre_variance               0.134048     0.013663 -0.014424
#           intensity_mean                0.135934    -0.068244 -0.070536
#           intensity_variance            1.000000     0.027947  0.045430
#           rhythm_mean                   0.027947     1.000000  0.338687
#           rhythm_                       0.045430     0.338687  1.000000

# %%
# library & dataset
import seaborn as sns
from matplotlib import pyplot as plt
# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="pitch_mean", y="timbre", data=songList, fit_reg=False, hue='p_mood', legend=False)
 
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')

# %%
sns.pairplot(songList.loc[:,songList.dtypes == 'float64'])

# %%
moods = ['happy','sad','energetic','calm']
for mood in moods:
    sns.kdeplot(songList[songList['p_mood']==mood]['acousticness'], shade=True,label=mood)

# %%
a = songList.dtypes == 'float64'
print(a.index)
for x in range(len(a)):
    
    if(a[x]):
        try:
            print(a.index[x])
            for mood in moods:
                g = sns.kdeplot(songList[songList['p_mood']==mood][a.index[x]], shade=True,label=mood)
            plt.show(g)
        except:
            print("didnt work")
# Out:
# Index(['acousticness', 'analysis_url', 'danceability', 'duration_ms', 'energy',
#        'id', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'p_creator', 'p_mood', 'p_name', 'speechiness', 'tempo',
#        'time_signature', 'track_href', 'type', 'uri', 'valence'],
#       dtype='object')
# acousticness
# danceability
# duration_ms
# energy
# instrumentalness
# key
# liveness
# loudness
# mode
# speechiness
# tempo
# time_signature
# didnt work
# valence

# %%
moods = ['happy','sad','energetic','calm']
for mood in moods:
    print(mood)
    g = sns.jointplot("acousticness", "instrumentalness", data=songList[songList['p_mood']==mood], kind='kde');
    plt.show(g)
# Out:
# happy
# sad
# energetic
# calm

# %%
songList[['acousticness','danceability','duration_ms','energy','instrumentalness','key','liveness','loudness','mode','speechiness','tempo','time_signature','valence']]
# Out:
#       acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0          0.06200         0.738     139813.0   0.717          0.000000  1.0
# 1          0.00575         0.862     186613.0   0.400          0.000007  4.0
# 2          0.30000         0.806     212867.0   0.546          0.000000  9.0
# 3          0.21400         0.529     178747.0   0.496          0.000000  0.0
# 4          0.00103         0.665     157220.0   0.712          0.003420  1.0
# ...            ...           ...          ...     ...               ...  ...
# 7706       0.03830         0.651     241711.0   0.793          0.022000  5.0
# 7707       0.69600         0.482     214558.0   0.631          0.024200  5.0
# 7708       0.17100         0.664     187040.0   0.724          0.000000  7.0
# 7709       0.59600         0.682     195573.0   0.443          0.005390  2.0
# 7710       0.28700         0.732     154456.0   0.413          0.000000  9.0
#
#       liveness  loudness  mode  speechiness    tempo  time_signature  valence
# 0       0.2050    -5.121   1.0       0.0573   98.047             4.0   0.5000
# 1       0.1230    -7.486   1.0       0.0736  122.963             4.0   0.5960
# 2       0.1020    -6.637   1.0       0.0575  147.986             4.0   0.8740
# 3       0.2120    -6.668   0.0       0.1510   74.619             4.0   0.5880
# 4       0.1020    -7.536   1.0       0.0527   93.989             4.0   0.6690
# ...        ...       ...   ...          ...      ...             ...      ...
# 7706    0.1780    -5.288   1.0       0.0837  146.070             4.0   0.2610
# 7707    0.2090    -6.917   1.0       0.0986  126.576             3.0   0.0743
# 7708    0.1300    -5.457   1.0       0.1160  144.052             4.0   0.6970
# 7709    0.2660   -10.787   0.0       0.0554   99.891             4.0   0.5820
# 7710    0.0565    -6.353   1.0       0.0702   92.066             4.0   0.7610
#
# [7711 rows x 13 columns]

# %%
X = songList[['acousticness','danceability','duration_ms','energy','instrumentalness','key','liveness','loudness','mode','speechiness','tempo','time_signature','valence']].to_numpy()
y = songList['p_mood'].to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)
print(gnb.score(X_test,y_test))
print(gnb.score(X_train,y_train))

print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# 0.4351771823681936
# 0.4445062071521215
# Number of mislabeled points out of a total 2314 points : 1307

# %%
clf = tree.DecisionTreeClassifier(random_state=1, max_depth=10)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(clf.score(X_test,y_test))
print(clf.score(X_train,y_train))

print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# 0.517286084701815
# 0.720585510468779
# Number of mislabeled points out of a total 2314 points : 1117

# %%
data = {'y_Actual':    y_test,
        'y_Predicted': y_pred
        }
df = pd.DataFrame(data, columns=['y_Actual','y_Predicted'])
confusion_matrix = pd.crosstab(df['y_Actual'], df['y_Predicted'], rownames=['Actual'], colnames=['Predicted'])

sns.heatmap(confusion_matrix, annot=True)
plt.show()

# %%
def getscore(num_steps, data):
    X = data.to_numpy()
    y = songList['p_mood'].to_numpy()
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
    clf = tree.DecisionTreeClassifier(max_depth=num_steps).fit(X_train,y_train)
    return [num_steps, clf.score(X_test,y_test), clf.score(X_train,y_train)]

# %%
scoreData = pd.DataFrame(columns=['num_steps','test_score','train_score'])
variables = ['acousticness','danceability','duration_ms','energy','instrumentalness','key','liveness','loudness','mode','speechiness','tempo','time_signature','valence']
data = songList[['danceability','energy','liveness','loudness','tempo','time_signature','valence']]
data.loc[:,'acousticness_instrumentalness'] = songList.loc[:,'acousticness']*songList.loc[:,'instrumentalness']
for x in range(1,10):
    scoreData.loc[len(scoreData)] = getscore(x,data)
data
# Out:
# /Users/admin/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/admin/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1048: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
#       danceability  energy  liveness  loudness    tempo  time_signature  \
# 0            0.738   0.717    0.2050    -5.121   98.047             4.0
# 1            0.862   0.400    0.1230    -7.486  122.963             4.0
# 2            0.806   0.546    0.1020    -6.637  147.986             4.0
# 3            0.529   0.496    0.2120    -6.668   74.619             4.0
# 4            0.665   0.712    0.1020    -7.536   93.989             4.0
# ...            ...     ...       ...       ...      ...             ...
# 7706         0.651   0.793    0.1780    -5.288  146.070             4.0
# 7707         0.482   0.631    0.2090    -6.917  126.576             3.0
# 7708         0.664   0.724    0.1300    -5.457  144.052             4.0
# 7709         0.682   0.443    0.2660   -10.787   99.891             4.0
# 7710         0.732   0.413    0.0565    -6.353   92.066             4.0
#
#       valence  acousticness_instrumentalness
# 0      0.5000                   0.000000e+00
# 1      0.5960                   4.306750e-08
# 2      0.8740                   0.000000e+00
# 3      0.5880                   0.000000e+00
# 4      0.6690                   3.522600e-06
# ...       ...                            ...
# 7706   0.2610                   8.426000e-04
# 7707   0.0743                   1.684320e-02
# 7708   0.6970                   0.000000e+00
# 7709   0.5820                   3.212440e-03
# 7710   0.7610                   0.000000e+00
#
# [7711 rows x 8 columns]

# %%
print(scoreData.iloc[3,:])
g = sns.regplot(x='num_steps',y='test_score',data=scoreData, scatter_kws={"s": 50}, order=2, ci=None)
g = sns.regplot(x='num_steps',y='train_score',data=scoreData, scatter_kws={"s": 50}, order=2, ci=None)
plt.show(g)
scoreData
# Out:
# num_steps      4.000000
# test_score     0.516854
# train_score    0.537336
# Name: 3, dtype: float64
#    num_steps  test_score  train_score
# 0        1.0    0.407087     0.408746
# 1        2.0    0.500432     0.508060
# 2        3.0    0.501296     0.512692
# 3        4.0    0.516854     0.537336
# 4        5.0    0.519879     0.561608
# 5        6.0    0.519447     0.577914
# 6        7.0    0.524201     0.603483
# 7        8.0    0.528954     0.634982
# 8        9.0    0.523336     0.671855
