# %%
import pandas as pd

# %%
songList = pd.read_csv('songlist.csv',index_col=0)

# %%
moods = ['happy','sad','energetic','calm']
for x in moods:
    print(x,': ',len(songList[songList['p_mood']==x]))
# Out:
# happy :  1547
# sad :  1862
# energetic :  1640
# calm :  2662

# %%
a = list(songList.columns)
a.remove('analysis_url')
a.remove('track_href')
a.remove('type')
a.remove('uri')
a.remove('id')
print(a)
songList[a]
# Out:
# ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'p_creator', 'p_mood', 'p_name', 'speechiness', 'tempo', 'time_signature', 'valence']
#       acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0          0.06200         0.738     139813.0   0.717          0.000000  1.0
# 1          0.00575         0.862     186613.0   0.400          0.000007  4.0
# 2          0.30000         0.806     212867.0   0.546          0.000000  9.0
# 3          0.21400         0.529     178747.0   0.496          0.000000  0.0
# 4          0.00103         0.665     157220.0   0.712          0.003420  1.0
# ...            ...           ...          ...     ...               ...  ...
# 7706       0.03830         0.651     241711.0   0.793          0.022000  5.0
# 7707       0.69600         0.482     214558.0   0.631          0.024200  5.0
# 7708       0.17100         0.664     187040.0   0.724          0.000000  7.0
# 7709       0.59600         0.682     195573.0   0.443          0.005390  2.0
# 7710       0.28700         0.732     154456.0   0.413          0.000000  9.0
#
#       liveness  loudness  mode   p_creator p_mood        p_name  speechiness  \
# 0       0.2050    -5.121   1.0     Spotify  happy  Mood Booster       0.0573
# 1       0.1230    -7.486   1.0     Spotify  happy  Mood Booster       0.0736
# 2       0.1020    -6.637   1.0     Spotify  happy  Mood Booster       0.0575
# 3       0.2120    -6.668   0.0     Spotify  happy  Mood Booster       0.1510
# 4       0.1020    -7.536   1.0     Spotify  happy  Mood Booster       0.0527
# ...        ...       ...   ...         ...    ...           ...          ...
# 7706    0.1780    -5.288   1.0  kristy bae  happy       b happy       0.0837
# 7707    0.2090    -6.917   1.0  kristy bae  happy       b happy       0.0986
# 7708    0.1300    -5.457   1.0  kristy bae  happy       b happy       0.1160
# 7709    0.2660   -10.787   0.0  kristy bae  happy       b happy       0.0554
# 7710    0.0565    -6.353   1.0  kristy bae  happy       b happy       0.0702
#
#         tempo  time_signature  valence
# 0      98.047             4.0   0.5000
# 1     122.963             4.0   0.5960
# 2     147.986             4.0   0.8740
# 3      74.619             4.0   0.5880
# 4      93.989             4.0   0.6690
# ...       ...             ...      ...
# 7706  146.070             4.0   0.2610
# 7707  126.576             3.0   0.0743
# 7708  144.052             4.0   0.6970
# 7709   99.891             4.0   0.5820
# 7710   92.066             4.0   0.7610
#
# [7711 rows x 16 columns]

# %%
group_by_mood = songList.groupby(by=['p_mood'])
group_by_mood.count()
# Out:
#            acousticness  analysis_url  danceability  duration_ms  energy  \
# p_mood
# calm               2662          2662          2662         2662    2662
# energetic          1640          1640          1640         1640    1640
# happy              1547          1547          1547         1547    1547
# sad                1862          1862          1862         1862    1862
#
#              id  instrumentalness   key  liveness  loudness  mode  p_creator  \
# p_mood
# calm       2662              2662  2662      2662      2662  2662       2662
# energetic  1640              1640  1640      1640      1640  1640       1640
# happy      1547              1547  1547      1547      1547  1547       1547
# sad        1862              1862  1862      1862      1862  1862       1862
#
#            p_name  speechiness  tempo  time_signature  track_href  type   uri  \
# p_mood
# calm         2662         2662   2662            2662        2662  2662  2662
# energetic    1640         1640   1640            1640        1640  1640  1640
# happy        1547         1547   1547            1547        1547  1547  1547
# sad          1862         1862   1862            1862        1862  1862  1862
#
#            valence
# p_mood
# calm          2662
# energetic     1640
# happy         1547
# sad           1862

# %%
group_by_mood = songList.groupby(by=['p_mood'])
group_by_mood.mean()
# Out:
#            acousticness  danceability    duration_ms    energy  \
# p_mood
# calm           0.618580      0.554614  200002.706987  0.356063
# energetic      0.179713      0.672137  209392.340854  0.700755
# happy          0.283512      0.647679  197340.027796  0.618014
# sad            0.518540      0.565607  217222.881847  0.424370
#
#            instrumentalness       key  liveness   loudness      mode  \
# p_mood
# calm               0.425413  5.329452  0.140197 -13.415992  0.682194
# energetic          0.044804  5.232927  0.180371  -5.968582  0.615854
# happy              0.112780  5.400129  0.174544  -7.982396  0.688429
# sad                0.034776  5.188507  0.146802  -9.393330  0.674544
#
#            speechiness       tempo  time_signature   valence
# p_mood
# calm          0.070975  111.058126        3.866642  0.344595
# energetic     0.095167  118.071947        3.990854  0.565945
# happy         0.083959  117.328536        3.960569  0.557846
# sad           0.078802  116.967701        3.857680  0.314881

# %%
songList.groupby(by=['p_mood']).corr()
# Out:
#                             acousticness  danceability  duration_ms    energy  \
# p_mood
# calm      acousticness          1.000000     -0.446542    -0.313308 -0.758689
#           danceability         -0.446542      1.000000    -0.007031  0.462632
#           duration_ms          -0.313308     -0.007031     1.000000  0.360116
#           energy               -0.758689      0.462632     0.360116  1.000000
#           instrumentalness      0.239073     -0.222423    -0.221699 -0.360865
#           key                  -0.026614      0.039185    -0.007882  0.029538
#           liveness             -0.098445      0.049427    -0.005285  0.135878
#           loudness             -0.608035      0.583804     0.216201  0.775402
#           mode                  0.113925     -0.133163     0.038111 -0.076056
#           speechiness          -0.040677      0.253948    -0.254808  0.004352
#           tempo                -0.125632      0.042747     0.107629  0.135246
#           time_signature       -0.138052      0.183147     0.086237  0.169619
#           valence              -0.255272      0.516616    -0.141713  0.319245
# energetic acousticness          1.000000     -0.025835     0.020754 -0.479317
#           danceability         -0.025835      1.000000    -0.087593 -0.048203
#           duration_ms           0.020754     -0.087593     1.000000 -0.039388
#           energy               -0.479317     -0.048203    -0.039388  1.000000
#           instrumentalness     -0.073610     -0.007923     0.051703  0.120344
#           key                  -0.004409      0.048503    -0.048109  0.020775
#           liveness             -0.067840     -0.084154    -0.051322  0.165321
#           loudness             -0.351241      0.038021    -0.132223  0.660970
#           mode                  0.054522     -0.081873    -0.013937 -0.024174
#           speechiness           0.035686      0.079384    -0.083718 -0.020146
#           tempo                -0.075247     -0.208966    -0.063216  0.112037
#           time_signature       -0.089672      0.130048    -0.013791  0.051594
#           valence              -0.071910      0.362042    -0.004551  0.258274
# happy     acousticness          1.000000     -0.272930    -0.263029 -0.702814
#           danceability         -0.272930      1.000000     0.041476  0.162352
#           duration_ms          -0.263029      0.041476     1.000000  0.235121
#           energy               -0.702814      0.162352     0.235121  1.000000
#           instrumentalness      0.429557     -0.326338    -0.254439 -0.500337
#           key                   0.018466      0.070543    -0.026502 -0.005337
#           liveness             -0.089878     -0.028862     0.043462  0.156263
#           loudness             -0.643295      0.356769     0.218691  0.798550
#           mode                  0.047955     -0.133090     0.027870  0.003222
#           speechiness           0.022649      0.109278    -0.087013 -0.035890
#           tempo                -0.095765     -0.134180     0.072168  0.112124
#           time_signature       -0.124609      0.135487     0.064325  0.152346
#           valence              -0.308793      0.343898     0.045340  0.414964
# sad       acousticness          1.000000     -0.268304    -0.011971 -0.732754
#           danceability         -0.268304      1.000000    -0.254383  0.244926
#           duration_ms          -0.011971     -0.254383     1.000000 -0.025877
#           energy               -0.732754      0.244926    -0.025877  1.000000
#           instrumentalness      0.050030     -0.096652     0.104913 -0.017418
#           key                  -0.018812      0.080166    -0.079714  0.036226
#           liveness             -0.033680      0.032534    -0.063746  0.102825
#           loudness             -0.559179      0.191397    -0.016574  0.754632
#           mode                  0.122124     -0.150607     0.073357 -0.103942
#           speechiness          -0.140980      0.216554    -0.119002  0.186075
#           tempo                -0.132242     -0.062283     0.009415  0.140448
#           time_signature       -0.166020      0.235771    -0.058576  0.184993
#           valence              -0.137959      0.391787    -0.231461  0.297955
#
#                             instrumentalness       key  liveness  loudness  \
# p_mood
# calm      acousticness              0.239073 -0.026614 -0.098445 -0.608035
#           danceability             -0.222423  0.039185  0.049427  0.583804
#           duration_ms              -0.221699 -0.007882 -0.005285  0.216201
#           energy                   -0.360865  0.029538  0.135878  0.775402
#           instrumentalness          1.000000  0.027184 -0.077156 -0.590350
#           key                       0.027184  1.000000  0.006451  0.029740
#           liveness                 -0.077156  0.006451  1.000000  0.130880
#           loudness                 -0.590350  0.029740  0.130880  1.000000
#           mode                     -0.138476 -0.127147 -0.002166 -0.024366
#           speechiness               0.121118  0.045515  0.047966  0.042121
#           tempo                    -0.124440  0.013787  0.029070  0.133296
#           time_signature           -0.112030  0.024165  0.048879  0.189693
#           valence                  -0.200466  0.041841  0.049534  0.351180
# energetic acousticness             -0.073610 -0.004409 -0.067840 -0.351241
#           danceability             -0.007923  0.048503 -0.084154  0.038021
#           duration_ms               0.051703 -0.048109 -0.051322 -0.132223
#           energy                    0.120344  0.020775  0.165321  0.660970
#           instrumentalness          1.000000 -0.039412  0.041903 -0.109122
#           key                      -0.039412  1.000000  0.043646  0.027706
#           liveness                  0.041903  0.043646  1.000000  0.095346
#           loudness                 -0.109122  0.027706  0.095346  1.000000
#           mode                     -0.035917 -0.166056 -0.031129 -0.018845
#           speechiness              -0.101235  0.008058  0.033338 -0.016575
#           tempo                     0.029306 -0.031249  0.013995  0.053182
#           time_signature            0.006985 -0.003193  0.046695  0.035321
#           valence                  -0.063430  0.016985  0.013821  0.189672
# happy     acousticness              0.429557  0.018466 -0.089878 -0.643295
#           danceability             -0.326338  0.070543 -0.028862  0.356769
#           duration_ms              -0.254439 -0.026502  0.043462  0.218691
#           energy                   -0.500337 -0.005337  0.156263  0.798550
#           instrumentalness          1.000000 -0.016183 -0.087027 -0.699936
#           key                      -0.016183  1.000000  0.050884 -0.008197
#           liveness                 -0.087027  0.050884  1.000000  0.125243
#           loudness                 -0.699936 -0.008197  0.125243  1.000000
#           mode                      0.013724 -0.098348 -0.010176 -0.067980
#           speechiness              -0.097226  0.023961  0.042568  0.034346
#           tempo                    -0.047905  0.047061  0.016562  0.047442
#           time_signature           -0.124792  0.012913  0.040770  0.173442
#           valence                  -0.209380  0.047719  0.025445  0.303254
# sad       acousticness              0.050030 -0.018812 -0.033680 -0.559179
#           danceability             -0.096652  0.080166  0.032534  0.191397
#           duration_ms               0.104913 -0.079714 -0.063746 -0.016574
#           energy                   -0.017418  0.036226  0.102825  0.754632
#           instrumentalness          1.000000 -0.015535  0.014913 -0.148001
#           key                      -0.015535  1.000000  0.003910  0.042956
#           liveness                  0.014913  0.003910  1.000000  0.036363
#           loudness                 -0.148001  0.042956  0.036363  1.000000
#           mode                      0.021320 -0.078929 -0.029546 -0.042816
#           speechiness              -0.084716  0.006682  0.085647  0.033231
#           tempo                    -0.004500 -0.012350 -0.009546  0.097911
#           time_signature           -0.023282  0.037441  0.009618  0.117683
#           valence                  -0.131165  0.074899  0.074951  0.204796
#
#                                 mode  speechiness     tempo  time_signature  \
# p_mood
# calm      acousticness      0.113925    -0.040677 -0.125632       -0.138052
#           danceability     -0.133163     0.253948  0.042747        0.183147
#           duration_ms       0.038111    -0.254808  0.107629        0.086237
#           energy           -0.076056     0.004352  0.135246        0.169619
#           instrumentalness -0.138476     0.121118 -0.124440       -0.112030
#           key              -0.127147     0.045515  0.013787        0.024165
#           liveness         -0.002166     0.047966  0.029070        0.048879
#           loudness         -0.024366     0.042121  0.133296        0.189693
#           mode              1.000000    -0.172745 -0.003600        0.009381
#           speechiness      -0.172745     1.000000 -0.025995        0.033744
#           tempo            -0.003600    -0.025995  1.000000        0.065309
#           time_signature    0.009381     0.033744  0.065309        1.000000
#           valence          -0.061990     0.231710  0.088768        0.117445
# energetic acousticness      0.054522     0.035686 -0.075247       -0.089672
#           danceability     -0.081873     0.079384 -0.208966        0.130048
#           duration_ms      -0.013937    -0.083718 -0.063216       -0.013791
#           energy           -0.024174    -0.020146  0.112037        0.051594
#           instrumentalness -0.035917    -0.101235  0.029306        0.006985
#           key              -0.166056     0.008058 -0.031249       -0.003193
#           liveness         -0.031129     0.033338  0.013995        0.046695
#           loudness         -0.018845    -0.016575  0.053182        0.035321
#           mode              1.000000    -0.098520 -0.004450        0.006592
#           speechiness      -0.098520     1.000000  0.113239        0.035940
#           tempo            -0.004450     0.113239  1.000000       -0.021183
#           time_signature    0.006592     0.035940 -0.021183        1.000000
#           valence          -0.031985     0.038202  0.014340        0.076967
# happy     acousticness      0.047955     0.022649 -0.095765       -0.124609
#           danceability     -0.133090     0.109278 -0.134180        0.135487
#           duration_ms       0.027870    -0.087013  0.072168        0.064325
#           energy            0.003222    -0.035890  0.112124        0.152346
#           instrumentalness  0.013724    -0.097226 -0.047905       -0.124792
#           key              -0.098348     0.023961  0.047061        0.012913
#           liveness         -0.010176     0.042568  0.016562        0.040770
#           loudness         -0.067980     0.034346  0.047442        0.173442
#           mode              1.000000    -0.120534  0.047252       -0.064209
#           speechiness      -0.120534     1.000000  0.048574        0.015500
#           tempo             0.047252     0.048574  1.000000        0.019843
#           time_signature   -0.064209     0.015500  0.019843        1.000000
#           valence           0.001277     0.026843  0.088421        0.111767
# sad       acousticness      0.122124    -0.140980 -0.132242       -0.166020
#           danceability     -0.150607     0.216554 -0.062283        0.235771
#           duration_ms       0.073357    -0.119002  0.009415       -0.058576
#           energy           -0.103942     0.186075  0.140448        0.184993
#           instrumentalness  0.021320    -0.084716 -0.004500       -0.023282
#           key              -0.078929     0.006682 -0.012350        0.037441
#           liveness         -0.029546     0.085647 -0.009546        0.009618
#           loudness         -0.042816     0.033231  0.097911        0.117683
#           mode              1.000000    -0.139240  0.024735       -0.097213
#           speechiness      -0.139240     1.000000  0.057826        0.088027
#           tempo             0.024735     0.057826  1.000000       -0.048074
#           time_signature   -0.097213     0.088027 -0.048074        1.000000
#           valence          -0.031252     0.155335  0.004314        0.106791
#
#                              valence
# p_mood
# calm      acousticness     -0.255272
#           danceability      0.516616
#           duration_ms      -0.141713
#           energy            0.319245
#           instrumentalness -0.200466
#           key               0.041841
#           liveness          0.049534
#           loudness          0.351180
#           mode             -0.061990
#           speechiness       0.231710
#           tempo             0.088768
#           time_signature    0.117445
#           valence           1.000000
# energetic acousticness     -0.071910
#           danceability      0.362042
#           duration_ms      -0.004551
#           energy            0.258274
#           instrumentalness -0.063430
#           key               0.016985
#           liveness          0.013821
#           loudness          0.189672
#           mode             -0.031985
#           speechiness       0.038202
#           tempo             0.014340
#           time_signature    0.076967
#           valence           1.000000
# happy     acousticness     -0.308793
#           danceability      0.343898
#           duration_ms       0.045340
#           energy            0.414964
#           instrumentalness -0.209380
#           key               0.047719
#           liveness          0.025445
#           loudness          0.303254
#           mode              0.001277
#           speechiness       0.026843
#           tempo             0.088421
#           time_signature    0.111767
#           valence           1.000000
# sad       acousticness     -0.137959
#           danceability      0.391787
#           duration_ms      -0.231461
#           energy            0.297955
#           instrumentalness -0.131165
#           key               0.074899
#           liveness          0.074951
#           loudness          0.204796
#           mode             -0.031252
#           speechiness       0.155335
#           tempo             0.004314
#           time_signature    0.106791
#           valence           1.000000

# %%
# library & dataset
import seaborn as sns
from matplotlib import pyplot as plt
# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="acousticness", y="instrumentalness", data=songList, fit_reg=False, hue='p_mood', legend=False)
 
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')
 
sns.plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-1e78713e68da> in <module>
#       8 plt.legend(loc='lower right')
#       9
# ---> 10 sns.plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'plt'

# %%
# Out:
#        acousticness  danceability    duration_ms       energy  \
# count    2662.00000   2662.000000    2662.000000  2662.000000
# mean        0.61858      0.554614  200002.706987     0.356063
# std         0.33527      0.190845   73225.612684     0.230789
# min         0.00001      0.000000   45427.000000     0.001700
# 25%         0.31200      0.440000  147587.750000     0.176250
# 50%         0.73200      0.587000  196753.500000     0.334500
# 75%         0.91175      0.693000  234127.250000     0.515000
# max         0.99600      0.957000  820174.000000     0.951000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       2662.000000  2662.000000  2662.000000  2662.000000  2662.000000
# mean           0.425413     5.329452     0.140197   -13.415992     0.682194
# std            0.423182     3.568520     0.101235     6.866084     0.465711
# min            0.000000     0.000000     0.026100   -39.367000     0.000000
# 25%            0.000126     2.000000     0.097925   -16.260500     0.000000
# 50%            0.281000     5.000000     0.110000   -11.329500     1.000000
# 75%            0.892000     8.000000     0.134000    -8.538750     1.000000
# max            0.997000    11.000000     0.986000    -2.270000     1.000000
#
#        speechiness        tempo  time_signature      valence
# count  2662.000000  2662.000000     2662.000000  2662.000000
# mean      0.070975   111.058126        3.866642     0.344595
# std       0.080677    31.819824        0.531481     0.221849
# min       0.000000     0.000000        0.000000     0.000000
# 25%       0.034500    83.258250        4.000000     0.165250
# 50%       0.043200   107.998500        4.000000     0.319000
# 75%       0.065800   131.986000        4.000000     0.493000
# max       0.865000   239.657000        5.000000     0.972000

# %%
songList[['acousticness','danceability','duration_ms','energy','instrumentalness','key','liveness','loudness','mode','speechiness','tempo','time_signature','valence']]
# Out:
#       acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0          0.06200         0.738     139813.0   0.717          0.000000  1.0
# 1          0.00575         0.862     186613.0   0.400          0.000007  4.0
# 2          0.30000         0.806     212867.0   0.546          0.000000  9.0
# 3          0.21400         0.529     178747.0   0.496          0.000000  0.0
# 4          0.00103         0.665     157220.0   0.712          0.003420  1.0
# ...            ...           ...          ...     ...               ...  ...
# 7706       0.03830         0.651     241711.0   0.793          0.022000  5.0
# 7707       0.69600         0.482     214558.0   0.631          0.024200  5.0
# 7708       0.17100         0.664     187040.0   0.724          0.000000  7.0
# 7709       0.59600         0.682     195573.0   0.443          0.005390  2.0
# 7710       0.28700         0.732     154456.0   0.413          0.000000  9.0
#
#       liveness  loudness  mode  speechiness    tempo  time_signature  valence
# 0       0.2050    -5.121   1.0       0.0573   98.047             4.0   0.5000
# 1       0.1230    -7.486   1.0       0.0736  122.963             4.0   0.5960
# 2       0.1020    -6.637   1.0       0.0575  147.986             4.0   0.8740
# 3       0.2120    -6.668   0.0       0.1510   74.619             4.0   0.5880
# 4       0.1020    -7.536   1.0       0.0527   93.989             4.0   0.6690
# ...        ...       ...   ...          ...      ...             ...      ...
# 7706    0.1780    -5.288   1.0       0.0837  146.070             4.0   0.2610
# 7707    0.2090    -6.917   1.0       0.0986  126.576             3.0   0.0743
# 7708    0.1300    -5.457   1.0       0.1160  144.052             4.0   0.6970
# 7709    0.2660   -10.787   0.0       0.0554   99.891             4.0   0.5820
# 7710    0.0565    -6.353   1.0       0.0702   92.066             4.0   0.7610
#
# [7711 rows x 13 columns]

# %%
features = songList[['acousticness','danceability','duration_ms','energy','instrumentalness','key','liveness','loudness','mode','speechiness','tempo','time_signature','valence']].to_numpy()
output = songList[['p_mood']].to_numpy()
# Out:
# array([[6.20000e-02, 7.38000e-01, 1.39813e+05, ..., 9.80470e+01,
#         4.00000e+00, 5.00000e-01],
#        [5.75000e-03, 8.62000e-01, 1.86613e+05, ..., 1.22963e+02,
#         4.00000e+00, 5.96000e-01],
#        [3.00000e-01, 8.06000e-01, 2.12867e+05, ..., 1.47986e+02,
#         4.00000e+00, 8.74000e-01],
#        ...,
#        [1.71000e-01, 6.64000e-01, 1.87040e+05, ..., 1.44052e+02,
#         4.00000e+00, 6.97000e-01],
#        [5.96000e-01, 6.82000e-01, 1.95573e+05, ..., 9.98910e+01,
#         4.00000e+00, 5.82000e-01],
#        [2.87000e-01, 7.32000e-01, 1.54456e+05, ..., 9.20660e+01,
#         4.00000e+00, 7.61000e-01]])

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
X = 
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
y_pred = gnb.fit(X_train, y_train).predict(X_test)
print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0], (y_test != y_pred).sum()))
