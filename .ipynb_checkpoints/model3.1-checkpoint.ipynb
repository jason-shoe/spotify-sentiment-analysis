# %%
import pandas as pd
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

# %%
songList = pd.read_csv('songlist3.csv',index_col=0)

# %%
moods = ['happy','sad','energetic','calm']
for x in moods:
    print(x,': ',len(songList[songList['p_mood']==x]))
# Out:
# happy :  1474
# sad :  1885
# energetic :  1330
# calm :  1565

# %%
a = list(songList.columns)
a.remove('analysis_url')
a.remove('track_href')
a.remove('type')
a.remove('uri')
a.remove('id')
print(a)
songList[a]
# Out:
# ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'p_creator', 'p_mood', 'p_name', 'speechiness', 'tempo', 'time_signature', 'valence']
#       acousticness  danceability  duration_ms  energy  instrumentalness   key  \
# 0          0.00496         0.733     236093.0   0.899          0.000047   0.0
# 1          0.01080         0.657     212107.0   0.695          0.000000   2.0
# 2          0.03030         0.796     319373.0   0.867          0.000003  10.0
# 3          0.18400         0.731     236920.0   0.738          0.000000   9.0
# 4          0.33100         0.942     296147.0   0.641          0.179000   7.0
# ...            ...           ...          ...     ...               ...   ...
# 6249       0.20800         0.771     219664.0   0.761          0.000000   1.0
# 6250       0.85300         0.794     342040.0   0.320          0.134000   1.0
# 6251       0.01210         0.675     155693.0   0.574          0.000011   6.0
# 6252       0.02630         0.675     185886.0   0.630          0.000000   4.0
# 6253       0.03970         0.707     243357.0   0.622          0.000000   0.0
#
#       liveness  loudness  mode    p_creator     p_mood  \
# 0       0.3720    -4.237   1.0      Spotify  energetic
# 1       0.0822    -4.493   1.0      Spotify  energetic
# 2       0.1340    -9.543   1.0      Spotify  energetic
# 3       0.2140    -8.125   0.0      Spotify  energetic
# 4       0.0280   -10.150   1.0      Spotify  energetic
# ...        ...       ...   ...          ...        ...
# 6249    0.0910    -4.727   0.0  bella renas        sad
# 6250    0.1120   -12.920   0.0  bella renas        sad
# 6251    0.1080    -8.066   1.0  bella renas        sad
# 6252    0.2840    -8.052   1.0  bella renas        sad
# 6253    0.1490    -6.951   1.0  bella renas        sad
#
#                           p_name  speechiness    tempo  time_signature  \
# 0     Working Out Together: HAIM       0.1430  127.086             4.0
# 1     Working Out Together: HAIM       0.0321   65.997             4.0
# 2     Working Out Together: HAIM       0.0309  120.682             4.0
# 3     Working Out Together: HAIM       0.0377  117.656             4.0
# 4     Working Out Together: HAIM       0.0333  114.443             4.0
# ...                          ...          ...      ...             ...
# 6249            Sad boys Sad Rap       0.0470  131.010             4.0
# 6250            Sad boys Sad Rap       0.1730  174.088             4.0
# 6251            Sad boys Sad Rap       0.0559  135.037             4.0
# 6252            Sad boys Sad Rap       0.0720   77.492             4.0
# 6253            Sad boys Sad Rap       0.0310  142.942             4.0
#
#       valence
# 0       0.760
# 1       0.683
# 2       0.971
# 3       0.958
# 4       0.966
# ...       ...
# 6249    0.277
# 6250    0.241
# 6251    0.482
# 6252    0.223
# 6253    0.223
#
# [6254 rows x 16 columns]

# %%
group_by_mood = songList.groupby(by=['p_mood'])
group_by_mood.count()
# Out:
#            acousticness  analysis_url  danceability  duration_ms  energy  \
# p_mood
# calm               1565          1565          1565         1565    1565
# energetic          1330          1330          1330         1330    1330
# happy              1474          1474          1474         1474    1474
# sad                1885          1885          1885         1885    1885
#
#              id  instrumentalness   key  liveness  loudness  mode  p_creator  \
# p_mood
# calm       1565              1565  1565      1565      1565  1565       1565
# energetic  1330              1330  1330      1330      1330  1330       1330
# happy      1474              1474  1474      1474      1474  1474       1474
# sad        1885              1885  1885      1885      1885  1885       1885
#
#            p_name  speechiness  tempo  time_signature  track_href  type   uri  \
# p_mood
# calm         1565         1565   1565            1565        1565  1565  1565
# energetic    1330         1330   1330            1330        1330  1330  1330
# happy        1474         1474   1474            1474        1474  1474  1474
# sad          1885         1885   1885            1885        1885  1885  1885
#
#            valence
# p_mood
# calm          1565
# energetic     1330
# happy         1474
# sad           1885

# %%
group_by_mood = songList.groupby(by=['p_mood'])
group_by_mood.mean()
# Out:
#            acousticness  danceability    duration_ms    energy  \
# p_mood
# calm           0.540459      0.619488  185836.604473  0.415670
# energetic      0.090727      0.701918  194593.669925  0.764268
# happy          0.164963      0.639421  205454.449796  0.725486
# sad            0.538587      0.575142  214777.107692  0.408366
#
#            instrumentalness       key  liveness   loudness      mode  \
# p_mood
# calm               0.375267  5.468371  0.151878 -10.742767  0.645367
# energetic          0.075964  5.318797  0.199658  -5.284962  0.578195
# happy              0.047851  5.179104  0.181635  -6.205636  0.753053
# sad                0.065414  5.109814  0.146002  -9.615972  0.667374
#
#            speechiness       tempo  time_signature   valence
# p_mood
# calm          0.086323  113.658117        3.899681  0.364414
# energetic     0.127232  126.898002        3.973684  0.468186
# happy         0.065623  119.462349        3.976934  0.595951
# sad           0.082236  115.785468        3.883289  0.316277

# %%
songList.groupby(by=['p_mood']).corr()
# Out:
#                             acousticness  danceability  duration_ms    energy  \
# p_mood
# calm      acousticness          1.000000     -0.127785    -0.280603 -0.694486
#           danceability         -0.127785      1.000000    -0.203189  0.002185
#           duration_ms          -0.280603     -0.203189     1.000000  0.359800
#           energy               -0.694486      0.002185     0.359800  1.000000
#           instrumentalness      0.280833      0.124116    -0.339326 -0.346075
#           key                   0.002175      0.042100    -0.009670  0.024084
#           liveness             -0.117376     -0.031046     0.034204  0.115827
#           loudness             -0.560993      0.046152     0.301401  0.737680
#           mode                  0.061072     -0.126976     0.098543 -0.021311
#           speechiness           0.062653      0.203246    -0.268514 -0.103523
#           tempo                -0.098917     -0.160260     0.111260  0.115375
#           time_signature       -0.153788      0.139199     0.068618  0.151640
#           valence              -0.185381      0.345219    -0.210599  0.220107
# energetic acousticness          1.000000      0.027395     0.024153 -0.262691
#           danceability          0.027395      1.000000    -0.087255 -0.396140
#           duration_ms           0.024153     -0.087255     1.000000  0.015105
#           energy               -0.262691     -0.396140     0.015105  1.000000
#           instrumentalness     -0.178859     -0.154841     0.011868  0.343585
#           key                   0.002300      0.033465    -0.050002 -0.027200
#           liveness             -0.075684     -0.112951     0.011884  0.184516
#           loudness             -0.118519     -0.249761    -0.002287  0.641924
#           mode                 -0.009675      0.029406     0.012249 -0.063243
#           speechiness          -0.025640      0.246416    -0.026934 -0.167202
#           tempo                -0.180637     -0.149535     0.020070  0.133341
#           time_signature       -0.024921      0.169937    -0.007517  0.072831
#           valence               0.138100      0.277344    -0.049781 -0.023704
#           energy           -0.031337    -0.002374  0.109821        0.028148
#           instrumentalness -0.039656    -0.057260  0.076673       -0.016579
#           key              -0.088629     0.056139  0.022019       -0.009685
#           liveness         -0.046504     0.026230  0.070086        0.009150
#           loudness         -0.047455     0.015927  0.022601        0.011374
#           mode              1.000000    -0.100250  0.043801       -0.046775
#           speechiness      -0.100250     1.000000  0.099795        0.000538
#           tempo             0.043801     0.099795  1.000000        0.023057
#           time_signature   -0.046775     0.000538  0.023057        1.000000
#           valence          -0.001167     0.001117  0.053687        0.072675
# sad       acousticness      0.098797    -0.172355 -0.166287       -0.125235
#           danceability     -0.149558     0.193407 -0.034038        0.207974
#           duration_ms       0.058681    -0.094539 -0.009772       -0.034618
#           energy           -0.071209     0.215983  0.169578        0.139891
#           instrumentalness  0.001049    -0.103288 -0.085293       -0.019310
#           key              -0.083194     0.003762  0.011155        0.050743
#           liveness         -0.015019     0.094640 -0.000777        0.032101
#           loudness         -0.015407     0.054036  0.155188        0.067440
#           mode              1.000000    -0.133024  0.012782       -0.082733
#           speechiness      -0.133024     1.000000  0.070174        0.061059
#           tempo             0.012782     0.070174  1.000000       -0.070023
#           time_signature   -0.082733     0.061059 -0.070023        1.000000
#           valence          -0.021087     0.179101  0.030759        0.115705
#
#                              valence
# p_mood
# calm      acousticness     -0.185381
#           danceability      0.345219
#           duration_ms      -0.210599
#           energy            0.220107
#           instrumentalness -0.122791
#           key               0.045250
#           liveness          0.070873
#           loudness          0.218883
#           mode             -0.069242
#           speechiness       0.226749
#           tempo             0.031722
#           time_signature    0.088548
#           valence           1.000000
# energetic acousticness      0.138100
#           danceability      0.277344
#           duration_ms      -0.049781
#           energy           -0.023704
#           instrumentalness -0.172105
#           key               0.049158
#           liveness         -0.048830
#           loudness          0.000132
#           mode             -0.050828
#           speechiness       0.051094
#           tempo            -0.000649
#           time_signature    0.019459
#           valence           1.000000
# happy     acousticness      0.029977
#           danceability      0.345183
#           duration_ms      -0.127226
#           energy            0.134844
#           instrumentalness -0.071081
#           key               0.025131
#           liveness         -0.019607
#           loudness          0.000634
#           mode             -0.001167
#           speechiness       0.001117
#           tempo             0.053687
#           time_signature    0.072675
#           valence           1.000000
# sad       acousticness     -0.203246
#           danceability      0.431185
#           duration_ms      -0.249642
#           energy            0.365271
#           instrumentalness -0.220593
#           key               0.086307
#           liveness          0.090303
#           loudness          0.308664
#           mode             -0.021087
#           speechiness       0.179101
#           tempo             0.030759
#           time_signature    0.115705
#           valence           1.000000

# %%
# library & dataset
import seaborn as sns
from matplotlib import pyplot as plt
# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="acousticness", y="instrumentalness", data=songList, fit_reg=False, hue='p_mood', legend=False)
 
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')

# %%
sns.pairplot(songList.loc[:,songList.dtypes == 'float64'])

# %%
moods = ['happy','sad','energetic','calm']
for mood in moods:
    sns.kdeplot(songList[songList['p_mood']==mood]['acousticness'], shade=True,label=mood)

# %%
a = songList.dtypes == 'float64'
print(a.index)
for x in range(len(a)):
    
    if(a[x]):
        try:
            print(a.index[x])
            for mood in moods:
                g = sns.kdeplot(songList[songList['p_mood']==mood][a.index[x]], shade=True,label=mood)
            plt.show(g)
        except:
            print("didnt work")
# Out:
# Index(['acousticness', 'analysis_url', 'danceability', 'duration_ms', 'energy',
#        'id', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'p_creator', 'p_mood', 'p_name', 'speechiness', 'tempo',
#        'time_signature', 'track_href', 'type', 'uri', 'valence'],
#       dtype='object')
# acousticness
# danceability
# duration_ms
# energy
# instrumentalness
# key
# liveness
# loudness
# mode
# didnt work
# speechiness
# tempo
# time_signature
# didnt work
# valence

# %%
moods = ['happy','sad','energetic','calm']
for mood in moods:
    print(mood)
    g = sns.jointplot("acousticness", "instrumentalness", data=songList[songList['p_mood']==mood], kind='kde');
    plt.show(g)
# Out:
# happy
# sad
# energetic
# calm

# %%
songList[['acousticness','danceability','duration_ms','energy','instrumentalness','key','liveness','loudness','mode','speechiness','tempo','time_signature','valence']]
# Out:
#       acousticness  danceability  duration_ms  energy  instrumentalness   key  \
# 0          0.00496         0.733     236093.0   0.899          0.000047   0.0
# 1          0.01080         0.657     212107.0   0.695          0.000000   2.0
# 2          0.03030         0.796     319373.0   0.867          0.000003  10.0
# 3          0.18400         0.731     236920.0   0.738          0.000000   9.0
# 4          0.33100         0.942     296147.0   0.641          0.179000   7.0
# ...            ...           ...          ...     ...               ...   ...
# 6249       0.20800         0.771     219664.0   0.761          0.000000   1.0
# 6250       0.85300         0.794     342040.0   0.320          0.134000   1.0
# 6251       0.01210         0.675     155693.0   0.574          0.000011   6.0
# 6252       0.02630         0.675     185886.0   0.630          0.000000   4.0
# 6253       0.03970         0.707     243357.0   0.622          0.000000   0.0
#
#       liveness  loudness  mode  speechiness    tempo  time_signature  valence
# 0       0.3720    -4.237   1.0       0.1430  127.086             4.0    0.760
# 1       0.0822    -4.493   1.0       0.0321   65.997             4.0    0.683
# 2       0.1340    -9.543   1.0       0.0309  120.682             4.0    0.971
# 3       0.2140    -8.125   0.0       0.0377  117.656             4.0    0.958
# 4       0.0280   -10.150   1.0       0.0333  114.443             4.0    0.966
# ...        ...       ...   ...          ...      ...             ...      ...
# 6249    0.0910    -4.727   0.0       0.0470  131.010             4.0    0.277
# 6250    0.1120   -12.920   0.0       0.1730  174.088             4.0    0.241
# 6251    0.1080    -8.066   1.0       0.0559  135.037             4.0    0.482
# 6252    0.2840    -8.052   1.0       0.0720   77.492             4.0    0.223
# 6253    0.1490    -6.951   1.0       0.0310  142.942             4.0    0.223
#
# [6254 rows x 13 columns]

# %%
X = songList[['acousticness','danceability','duration_ms','energy','instrumentalness','key','liveness','loudness','mode','speechiness','tempo','time_signature','valence']].to_numpy()
y = songList['p_mood'].to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)
print(gnb.score(X_test,y_test))
print(gnb.score(X_train,y_train))

print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# 0.4789557805007991
# 0.4843500114233493
# Number of mislabeled points out of a total 1877 points : 978

# %%
clf = tree.DecisionTreeClassifier(random_state=1, max_depth=10)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(clf.score(X_test,y_test))
print(clf.score(X_train,y_train))

print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# 0.5919019712306872
# 0.8062599954306603
# Number of mislabeled points out of a total 1877 points : 766

# %%
data = {'y_Actual':    y_test,
        'y_Predicted': y_pred
        }
df = pd.DataFrame(data, columns=['y_Actual','y_Predicted'])
confusion_matrix = pd.crosstab(df['y_Actual'], df['y_Predicted'], rownames=['Actual'], colnames=['Predicted'])

sns.heatmap(confusion_matrix, annot=True)
plt.show()

# %%
def getscore(num_steps, data,y_var):
    X = data.to_numpy()
    y = y_var.to_numpy()
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
    clf = tree.DecisionTreeClassifier(max_depth=num_steps).fit(X_train,y_train)
    return [num_steps, clf.score(X_test,y_test), clf.score(X_train,y_train)]

# %%
scoreData = pd.DataFrame(columns=['num_steps','test_score','train_score'])
variables = ['acousticness','danceability','duration_ms','energy','instrumentalness','key','liveness','loudness','mode','speechiness','tempo','time_signature','valence']
data = songList[songList['p_mood'] != 'energetic'][['danceability','energy','liveness','loudness','tempo','time_signature','valence']]
y_var = songList[songList['p_mood'] != 'energetic']['p_mood']
data.loc[:,'acousticness_instrumentalness'] = songList.loc[:,'acousticness']*songList.loc[:,'instrumentalness']
for x in range(1,10):
    scoreData.loc[len(scoreData)] = getscore(x,data, y_var)
data
# Out:
#       danceability  energy  liveness  loudness    tempo  time_signature  \
# 1330         0.640   0.648    0.0802    -8.113   92.977             4.0
# 1331         0.669   0.801    0.0594    -5.445  109.919             4.0
# 1332         0.852   0.698    0.0773    -7.206  113.039             4.0
# 1333         0.460   0.800    0.1210    -3.584  102.460             4.0
# 1334         0.732   0.850    0.0388    -5.999  124.024             4.0
# ...            ...     ...       ...       ...      ...             ...
# 6249         0.771   0.761    0.0910    -4.727  131.010             4.0
# 6250         0.794   0.320    0.1120   -12.920  174.088             4.0
# 6251         0.675   0.574    0.1080    -8.066  135.037             4.0
# 6252         0.675   0.630    0.2840    -8.052   77.492             4.0
# 6253         0.707   0.622    0.1490    -6.951  142.942             4.0
#
#       valence  acousticness_instrumentalness
# 1330    0.548                   0.000000e+00
# 1331    0.541                   0.000000e+00
# 1332    0.324                   8.641700e-09
# 1333    0.553                   1.780240e-06
# 1334    0.372                   2.302800e-07
# ...       ...                            ...
# 6249    0.277                   0.000000e+00
# 6250    0.241                   1.143020e-01
# 6251    0.482                   1.343100e-07
# 6252    0.223                   0.000000e+00
# 6253    0.223                   0.000000e+00
#
# [4924 rows x 8 columns]

# %%
print(scoreData.iloc[3,:])
g = sns.regplot(x='num_steps',y='test_score',data=scoreData, scatter_kws={"s": 50}, order=2, ci=None)
g = sns.regplot(x='num_steps',y='train_score',data=scoreData, scatter_kws={"s": 50}, order=2, ci=None)
plt.show(g)
scoreData
# Out:
# num_steps      4.000000
# test_score     0.669147
# train_score    0.695879
# Name: 3, dtype: float64
#    num_steps  test_score  train_score
# 0        1.0    0.531800     0.556587
# 1        2.0    0.636671     0.663378
# 2        3.0    0.665088     0.689785
# 3        4.0    0.669147     0.695879
# 4        5.0    0.669147     0.718804
# 5        6.0    0.673207     0.736796
# 6        7.0    0.664411     0.768137
# 7        8.0    0.657645     0.788450
# 8        9.0    0.656969     0.818340
